# %%
# pip install pandas
import pandas as pd

# %%
data = {"Name": ["Alice", "Fitz", "Oyindamola", "Victoria"],
        "Age": [25, 30, 35, 40],
        "City": ["New York", "London", "Paris", "Tokyo"]
}

# %%
df = pd.DataFrame(data)

# %%
df # gives a preview of our dataset.
# Out:
#          Name  Age      City
# 0       Alice   25  New York
# 1        Fitz   30    London
# 2  Oyindamola   35     Paris
# 3    Victoria   40     Tokyo

# %% [markdown]
# - Trying to Extract Basic information from our dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df.shape #  (rows, columns)
# Out:
# (4, 3)

# %%
df.describe() # statistical insights on numerical columns of the datasets
# Out:
#              Age
# count   4.000000
# mean   32.500000
# std     6.454972
# min    25.000000
# 25%    28.750000
# 50%    32.500000
# 75%    36.250000
# max    40.000000

# %%
df["Name"]
# Out:
# 0         Alice
# 1          Fitz
# 2    Oyindamola
# 3      Victoria
# Name: Name, dtype: object

# %%
df["Age"]
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# Name: Age, dtype: int64

# %%
df["City"]
# Out:
# 0    New York
# 1      London
# 2       Paris
# 3       Tokyo
# Name: City, dtype: object

# %%
df.iloc[0]
# Out:
# Name       Alice
# Age           25
# City    New York
# Name: 0, dtype: object

# %%
df.iloc[2]
# Out:
# Name    Oyindamola
# Age             35
# City         Paris
# Name: 2, dtype: object

# %%
df
# Out:
#          Name  Age      City
# 0       Alice   25  New York
# 1        Fitz   30    London
# 2  Oyindamola   35     Paris
# 3    Victoria   40     Tokyo

# %%
df.iloc[0:2]
# Out:
#     Name  Age      City
# 0  Alice   25  New York
# 1   Fitz   30    London

# %%
df
# Out:
#          Name  Age      City
# 0       Alice   25  New York
# 1        Fitz   30    London
# 2  Oyindamola   35     Paris
# 3    Victoria   40     Tokyo

# %%
# df[condition]
# trying to extract for Ages greater than 30

condition = df["Age"]>30
df[condition]
#df[df["Age"]>30]
# Out:
#          Name  Age   City
# 2  Oyindamola   35  Paris
# 3    Victoria   40  Tokyo

# %%
df
# Out:
#          Name  Age      City
# 0       Alice   25  New York
# 1        Fitz   30    London
# 2  Oyindamola   35     Paris
# 3    Victoria   40     Tokyo

# %% [markdown]
# # Sorting our Dataframe

# %%
df.sort_values(by="City") # in ascending order
# Out:
#          Name  Age      City
# 1        Fitz   30    London
# 0       Alice   25  New York
# 2  Oyindamola   35     Paris
# 3    Victoria   40     Tokyo

# %%
df.sort_values(by="Age", ascending = False) # in descending order
# Out:
#          Name  Age      City
# 3    Victoria   40     Tokyo
# 2  Oyindamola   35     Paris
# 1        Fitz   30    London
# 0       Alice   25  New York

# %%
df
# Out:
#          Name  Age      City
# 0       Alice   25  New York
# 1        Fitz   30    London
# 2  Oyindamola   35     Paris
# 3    Victoria   40     Tokyo

# %%
df['Country'] = ["USA", "UK", "France", "Japan"]

# %%
df
# Out:
#          Name  Age      City Country
# 0       Alice   25  New York     USA
# 1        Fitz   30    London      UK
# 2  Oyindamola   35     Paris  France
# 3    Victoria   40     Tokyo   Japan

# %% [markdown]
# - Update information in our dataset

# %%
# we are trying to update Alice age in the dataset
df.loc[0,"Age"] = 50
# df.loc['first row index', 'column we are trying make the substitution'] = 'Value you want to be substituted'

# %%
df
# Out:
#          Name  Age      City Country
# 0       Alice   50  New York     USA
# 1        Fitz   30    London      UK
# 2  Oyindamola   35     Paris  France
# 3    Victoria   40     Tokyo   Japan

# %%
df['Age'].mean()
# Out:
# np.float64(38.75)

# %%
df['Age'].max()
# Out:
# 50

# %%
df['Age'].min()
# Out:
# 30

# %%
powers_df = pd.read_csv("/content/super_hero_powers.csv")

# %%
powers_df
# Out:
#                 Unnamed: 0  3-D Man  A-Bomb  Abe Sapien  Abin Sur  \
# 0                  Agility     True   False        True     False
# 1      Accelerated Healing    False    True        True     False
# 2       Lantern Power Ring    False   False       False      True
# 3    Dimensional Awareness    False   False       False     False
# 4          Cold Resistance    False   False        True     False
# ..                     ...      ...     ...         ...       ...
# 162          Phoenix Force    False   False       False     False
# 163  Molecular Dissipation    False   False       False     False
# 164          Vision - Cryo    False   False       False     False
# 165            Omnipresent    False   False       False     False
# 166             Omniscient    False   False       False     False
#
#      Abomination  Abraxas  Absorbing Man  Adam Monroe  Adam Strange  ...  \
# 0          False    False          False        False         False  ...
# ...

# %%
heroes_df = pd.read_csv("/content/heroes_information.csv")

# %%
heroes_df
# Out:
#      Unnamed: 0             name  Gender Eye color               Race  \
# 0             0           A-Bomb    Male    yellow              Human
# 1             1       Abe Sapien    Male      blue      Icthyo Sapien
# 2             2         Abin Sur    Male      blue            Ungaran
# 3             3      Abomination    Male     green  Human / Radiation
# 4             4          Abraxas    Male      blue      Cosmic Entity
# ..          ...              ...     ...       ...                ...
# 729         729  Yellowjacket II  Female      blue              Human
# 730         730             Ymir    Male     white        Frost Giant
# 731         731             Yoda    Male     brown     Yoda's species
# 732         732          Zatanna  Female      blue              Human
# 733         733             Zoom    Male       red                  -
#
#            Hair color  Height          Publisher Skin color Alignment  Weight
# ...

# %% [markdown]
# - Load Data with Pandas
# - Perform Data Cleaning Operations
# - Perform Data Aggregation
# - Formulate our data to also answer our questions

# %%
heroes_df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %%
heroes_df.tail()
# Out:
#      Unnamed: 0             name  Gender Eye color            Race  \
# 729         729  Yellowjacket II  Female      blue           Human
# 730         730             Ymir    Male     white     Frost Giant
# 731         731             Yoda    Male     brown  Yoda's species
# 732         732          Zatanna  Female      blue           Human
# 733         733             Zoom    Male       red               -
#
#            Hair color  Height      Publisher Skin color Alignment  Weight
# 729  Strawberry Blond   165.0  Marvel Comics          -      good    52.0
# 730           No Hair   304.8  Marvel Comics      white      good   -99.0
# 731             White    66.0   George Lucas      green      good    17.0
# 732             Black   170.0      DC Comics          -      good    57.0
# 733             Brown   185.0      DC Comics          -       bad    81.0

# %%
heroes_df.shape
# Out:
# (734, 11)

# %%
heroes_df.columns # gives a list of all the columns
# Out:
# Index(['Unnamed: 0', 'name', 'Gender', 'Eye color', 'Race', 'Hair color',
#        'Height', 'Publisher', 'Skin color', 'Alignment', 'Weight'],
#       dtype='object')

# %%
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  734 non-null    int64
#  1   name        734 non-null    object
#  2   Gender      734 non-null    object
#  3   Eye color   734 non-null    object
#  4   Race        734 non-null    object
#  5   Hair color  734 non-null    object
#  6   Height      734 non-null    float64
#  7   Publisher   719 non-null    object
#  8   Skin color  734 non-null    object
#  9   Alignment   734 non-null    object
#  10  Weight      732 non-null    float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 63.2+ KB

# %%
heroes_df.shape
# Out:
# (734, 11)

# %%
heroes_df.isnull().sum() # have a preview of the null values in our dataset
# Out:
# Unnamed: 0     0
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %%
heroes_df
# Out:
#      Unnamed: 0             name  Gender Eye color               Race  \
# 0             0           A-Bomb    Male    yellow              Human
# 1             1       Abe Sapien    Male      blue      Icthyo Sapien
# 2             2         Abin Sur    Male      blue            Ungaran
# 3             3      Abomination    Male     green  Human / Radiation
# 4             4          Abraxas    Male      blue      Cosmic Entity
# ..          ...              ...     ...       ...                ...
# 729         729  Yellowjacket II  Female      blue              Human
# 730         730             Ymir    Male     white        Frost Giant
# 731         731             Yoda    Male     brown     Yoda's species
# 732         732          Zatanna  Female      blue              Human
# 733         733             Zoom    Male       red                  -
#
#            Hair color  Height          Publisher Skin color Alignment  Weight
# ...

# %%
heroes_df = heroes_df.fillna('Unknown')

# %%
heroes_df.isnull().sum()
# Out:
# Unnamed: 0    0
# name          0
# Gender        0
# Eye color     0
# Race          0
# Hair color    0
# Height        0
# Publisher     0
# Skin color    0
# Alignment     0
# Weight        0
# dtype: int64

# %%
heroes_df.head(10)
# Out:
#    Unnamed: 0           name  Gender Eye color               Race Hair color  \
# 0           0         A-Bomb    Male    yellow              Human    No Hair
# 1           1     Abe Sapien    Male      blue      Icthyo Sapien    No Hair
# 2           2       Abin Sur    Male      blue            Ungaran    No Hair
# 3           3    Abomination    Male     green  Human / Radiation    No Hair
# 4           4        Abraxas    Male      blue      Cosmic Entity      Black
# 5           5  Absorbing Man    Male      blue              Human    No Hair
# 6           6    Adam Monroe    Male      blue                  -      Blond
# 7           7   Adam Strange    Male      blue              Human      Blond
# 8           8       Agent 13  Female      blue                  -      Blond
# 9           9      Agent Bob    Male     brown              Human      Brown
#
#    Height          Publisher Skin color Alignment Weight
# 0   203.0      Marvel Comics          -      good  441.0
# ...

# %%
heroes_df['Skin color'] = heroes_df['Skin color'].replace("-","No color")

# %%
heroes_df
# Out:
#      Unnamed: 0             name  Gender Eye color               Race  \
# 0             0           A-Bomb    Male    yellow              Human
# 1             1       Abe Sapien    Male      blue      Icthyo Sapien
# 2             2         Abin Sur    Male      blue            Ungaran
# 3             3      Abomination    Male     green  Human / Radiation
# 4             4          Abraxas    Male      blue      Cosmic Entity
# ..          ...              ...     ...       ...                ...
# 729         729  Yellowjacket II  Female      blue              Human
# 730         730             Ymir    Male     white        Frost Giant
# 731         731             Yoda    Male     brown     Yoda's species
# 732         732          Zatanna  Female      blue              Human
# 733         733             Zoom    Male       red                  -
#
#            Hair color  Height          Publisher Skin color Alignment Weight
# ...

# %%
heroes_df = heroes_df.drop("Unnamed: 0",axis = 1) # axis = 1 means column, axis = 0 means row

# %%
heroes_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
# ...

# %%
heroes_df['Height'] = heroes_df['Height'].astype(int)

# astype ... basically trying convert from one data type to the other

# %%
heroes_df['Height']
# Out:
# 0      203
# 1      191
# 2      185
# 3      203
# 4      -99
#       ...
# 729    165
# 730    304
# 731     66
# 732    170
# 733    185
# Name: Height, Length: 734, dtype: int64

# %%
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        734 non-null    object
#  1   Gender      734 non-null    object
#  2   Eye color   734 non-null    object
#  3   Race        734 non-null    object
#  4   Hair color  734 non-null    object
#  5   Height      734 non-null    int64
#  6   Publisher   734 non-null    object
#  7   Skin color  734 non-null    object
#  8   Alignment   734 non-null    object
#  9   Weight      734 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 57.5+ KB

# %%
heroes_df['Weight'].dtype
# Out:
# dtype('O')

# %%
heroes_df['Weight'].iloc[284:289]
# Out:
# 284      268.0
# 285       50.0
# 286    Unknown
# 287      -99.0
# 288       62.0
# Name: Weight, dtype: object

# %%
condition = heroes_df['Weight']=='Unknown'
heroes_df = heroes_df.drop(heroes_df[condition].index)

# %%
heroes_df['Weight'] = pd.to_numeric(heroes_df['Weight'])

# %%
heroes_df['Weight'].dtype
# Out:
# dtype('float64')

# %%
heroes_df['Weight'] = heroes_df['Weight'].astype(int)

# %%
heroes_df.head(10)
# Out:
#             name  Gender Eye color               Race Hair color  Height  \
# 0         A-Bomb    Male    yellow              Human    No Hair     203
# 1     Abe Sapien    Male      blue      Icthyo Sapien    No Hair     191
# 2       Abin Sur    Male      blue            Ungaran    No Hair     185
# 3    Abomination    Male     green  Human / Radiation    No Hair     203
# 4        Abraxas    Male      blue      Cosmic Entity      Black     -99
# 5  Absorbing Man    Male      blue              Human    No Hair     193
# 6    Adam Monroe    Male      blue                  -      Blond     -99
# 7   Adam Strange    Male      blue              Human      Blond     185
# 8       Agent 13  Female      blue                  -      Blond     173
# 9      Agent Bob    Male     brown              Human      Brown     178
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics   No color      good     441
# 1  Dark Horse Comics       blue      good      65
# ...

# %%
heroes_df['Race'] = heroes_df['Race'].replace('-', 'Unavailable')

# %%
heroes_df.head(10)
# Out:
#             name  Gender Eye color               Race Hair color  Height  \
# 0         A-Bomb    Male    yellow              Human    No Hair     203
# 1     Abe Sapien    Male      blue      Icthyo Sapien    No Hair     191
# 2       Abin Sur    Male      blue            Ungaran    No Hair     185
# 3    Abomination    Male     green  Human / Radiation    No Hair     203
# 4        Abraxas    Male      blue      Cosmic Entity      Black     -99
# 5  Absorbing Man    Male      blue              Human    No Hair     193
# 6    Adam Monroe    Male      blue        Unavailable      Blond     -99
# 7   Adam Strange    Male      blue              Human      Blond     185
# 8       Agent 13  Female      blue        Unavailable      Blond     173
# 9      Agent Bob    Male     brown              Human      Brown     178
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics   No color      good     441
# 1  Dark Horse Comics       blue      good      65
# ...

# %%
# absolute in maths is removing negative signs... i.e. -23 is 23 , -90 is 90 .. etc.

# %%
# heroes_df.abs() # works only if the dataset is all numeric

# %%
heroes_df['Weight'] = heroes_df['Weight'].abs()

# %%
heroes_df['Height'] = heroes_df['Height'].abs()

# %%
heroes_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red        Unavailable             Brown
#
# ...

# %%
heroes_df = heroes_df.rename(columns={'Weight':'Weight (kg)', 'Height':'Height (cm)'})

# %%
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height (cm)  \
# 0       A-Bomb   Male    yellow              Human    No Hair          203
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair          191
# 2     Abin Sur   Male      blue            Ungaran    No Hair          185
# 3  Abomination   Male     green  Human / Radiation    No Hair          203
# 4      Abraxas   Male      blue      Cosmic Entity      Black           99
#
#            Publisher Skin color Alignment  Weight (kg)
# 0      Marvel Comics   No color      good          441
# 1  Dark Horse Comics       blue      good           65
# 2          DC Comics        red      good           90
# 3      Marvel Comics   No color       bad          441
# 4      Marvel Comics   No color       bad           99

# %%
heroes_df['Height (cm)'].mean()
# Out:
# np.float64(161.03825136612022)

# %%
heroes_df['Height (cm)'].max()
# Out:
# 975

# %%
heroes_df['Gender'].unique()
# Out:
# array(['Male', 'Female', '-'], dtype=object)

# %%
heroes_df['Gender'] = heroes_df['Gender'].replace('-', 'Unspecified')

# %%
heroes_df['Gender'].unique()
# Out:
# array(['Male', 'Female', 'Unspecified'], dtype=object)

# %%
# Trying to get the avergae weight by Gender
heroes_df.groupby('Gender')['Weight (kg)'].mean()
# Out:
# Gender
# Female          84.685000
# Male           116.873016
# Unspecified    113.821429
# Name: Weight (kg), dtype: float64

# %%
powers_df.head(7)
# Out:
#               Unnamed: 0  3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# 0                Agility     True   False        True     False        False
# 1    Accelerated Healing    False    True        True     False         True
# 2     Lantern Power Ring    False   False       False      True        False
# 3  Dimensional Awareness    False   False       False     False        False
# 4        Cold Resistance    False   False        True     False        False
# 5             Durability    False    True        True     False        False
# 6                Stealth    False   False       False     False        False
#
#    Abraxas  Absorbing Man  Adam Monroe  Adam Strange  ...  Wonder Man  \
# 0    False          False        False         False  ...       False
# 1    False          False         True         False  ...       False
# 2    False          False        False         False  ...       False
# 3     True          False        False         False  ...       False
# ...
